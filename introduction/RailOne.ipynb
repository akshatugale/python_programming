# %%
class railone: 
    def __init__(self,train_name,passanger_name
                 ,age,sex,seat_no):
        self.train_name = train_name
        self.passanger_name = passanger_name
        self.age = age
        self.sex = sex
        self.seat_no = seat_no

    def train_info(self):
        print(f'the train name is P{self.train_name}')

    def passanger_info(self):
        print(f'The passanger name is {self.passanger_name}')
        print(f'the age of passanger is {self.age}')
        print(f'the sex of passanger is {self.sex}')
        print(f'the seat no of passanger is {self.seat_no}')

train_name = input('enter the train name :')
passanger_name = input('enter the passanger name :')
age = int(input('enter the  age :'))
sex = input('enter the sex :')
seat_no = int(input('enter the seat no : '))

railone_123 = railone(train_name, passanger_name, age, sex,  seat_no)

# %%
railone_123.passanger_info()
# Out:
# The passanger name is akshat
# the age of passanger is 20
# the sex of passanger is male
# the seat no of passanger is 12
