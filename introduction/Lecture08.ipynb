# %%
'''
class and objecct:
class: blueprint or template
object: instance of class

Note:
1. any function when defined inside a class is called "Methods of Reespective Class"
2. any variable when defined inside a class called "Attribute of Respective Class"

'''
#Blueprint/template: class bank 
class bank :

#Constructor/Special function / Special method
    def __init__(self,name):
        self.name = name #Attribute1

    def emp(self): #Method
        name = self.name #Attribute1

#define object : sbi
sbi = bank('india')

# %%
class motor:

    def __init__(self,wheel,color,engine):
        self.wheel = wheel
        self.color = color
        self.engine = engine

    def sound(self):
        print('beep')


tata = motor(4, 'navy blue' , 'EV')
bmw = motor(4,'black' , 'power')
audi = motor(4,'red','diesel')
suzuki = motor(4,'white','petrol')

# %%
bmw.sound()
# Out:
# beep

# %%
bmw.engine
# Out:
# 'power'

# %%
bmw.wheel
# Out:
# 4
