# %%
#Concepts of indexing and slicing 

a = "Hello World"
print(a[0::2])
print(a[-1::-1])
# Out:
# HloWrd
# dlroW olleH

# %%
#Write a program wether the entered string is palidrom or not 

string = input( ' Enter the String ')

string1 = string[::-1]

string == string1
False
if string == string1:
    print('The given is palindrom')
else:
    print('The given is not palindrom')

marks = float(input('Enter the marks'))
if marks >= 90:
    print(" Grade A+ ")
elif marks >= 75:
    print( " Grade A ")
elif marks >= 60:
    print( " Grade B ")
elif marks >= 40:
    print( " Grade c")
else:
    print("Fail")
