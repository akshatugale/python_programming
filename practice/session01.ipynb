# %%
str1 = "Hello"
str2 = "World"

#Checking data types of the string 
print("Data type of str1:", type(str1))
# Out:
# Data type of str1: <class 'str'>

# %%
#Checking the length of the string
print("Length of str1:", len(str1))
# Out:
# Length of str1: 5

# %%
#Concatenation
greeting = str1 + " " + str2
print(greeting)
# Out:
# Hello World

# %%
#Methods of string

#1 convert to uppercase
print(greeting.upper())
# Out:
# HELLO WORLD

# %%
#2 convert to lowercase 
print(greeting.lower())
# Out:
# hello world

# %%
#3 split the string into a list 
print(greeting.replace("World","Python"))
# Out:
# Hello Python

# %%
#Concept of f-string and format method 
name = "Akshat ugale"
age = 20

#using f-string
print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Akshat ugale and I am 20 years old.

# %%
#using format method 
print("My name is {} and I am {} years old.".format(name,age))
# Out:
# My name is Akshat ugale and I am 20 years old.
